# %%
# REFERENCE
#https://www.analyticsvidhya.com/blog/2016/08/beginners-guide-to-topic-modeling-in-python/#
import pandas as pd

# %%
lyr=pd.read_csv('final_matrix_with_writers.csv')

# %%
lyr.T
# Out:
#                                                                      0      \
# ARTIST                                                         Yo La Tengo
# ISRC                                                          USMTD0985602
# SPOTIFY_ID                                          158mw0CsuSHxTVWpMwN2Lp
# TITLE                                       Avalon or Someone Very Similar
# lyrics                   \n\nAvalon, how did these things happen? Avalo...
# song_id                                                            1369717
# producer                                                ['Roger Moutenot']
# number_of_tracks                                                       143
# number_of_albums                                                        40
# number_of_playlists                                                    649
# playlist_followers                                                 7559126
# highest_song_popularity                                                 62
# average_song_popularity                                            31.5506
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                          31
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            1
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     1
# Hip-Hop                                                                  0
# Indie                                                                    1
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    1
# Pop                                                                      1
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 1
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 0
# writer                                                                  []
#
#                                                                      1      \
# ARTIST                                                         Yo La Tengo
# ISRC                                                          USGKX9802104
# SPOTIFY_ID                                          7iX2vtYJlemPod7080OxTG
# TITLE                                                       Swing For Life
# lyrics                   \n\nOh, true rider, fasten me\nI saw a mystery...
# song_id                                                            1063052
# producer                                                                []
# number_of_tracks                                                       143
# number_of_albums                                                        40
# number_of_playlists                                                    649
# playlist_followers                                                 7559126
# highest_song_popularity                                                 62
# average_song_popularity                                            31.5506
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                          20
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            1
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     1
# Hip-Hop                                                                  0
# Indie                                                                    1
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    1
# Pop                                                                      1
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 1
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 0
# writer                                                                  []
#
#                                                                      2      \
# ARTIST                                                         Yo La Tengo
# ISRC                                                          USMTD1810576
# SPOTIFY_ID                                          2YmjVaikl30rmZZzlGTwPE
# TITLE                                                                Ashes
# lyrics                   \n\nI put spots on a bird of paradise, snake e...
# song_id                                                            3596137
# producer                                                   ['Yo La Tengo']
# number_of_tracks                                                       143
# number_of_albums                                                        40
# number_of_playlists                                                    649
# playlist_followers                                                 7559126
# highest_song_popularity                                                 62
# average_song_popularity                                            31.5506
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                          52
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            1
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     1
# Hip-Hop                                                                  0
# Indie                                                                    1
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    1
# Pop                                                                      1
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 1
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 0
# writer                     ['James McNew', 'Ira Kaplan', 'Georgia Hubley']
#
#                                                                      3      \
# ARTIST                                                           Smrtdeath
# ISRC                                                          QZANL1773974
# SPOTIFY_ID                                          4sBj3qUIPBkIMcRVlh6iXI
# TITLE                                                         Let It Bleed
# lyrics                   \n\n[Intro]\nSethany, Sethany, Sethany\nYeah, ...
# song_id                                                            3150542
# producer                                                   ['Taxpurposes']
# number_of_tracks                                                        10
# number_of_albums                                                        10
# number_of_playlists                                                     30
# playlist_followers                                                  425030
# highest_song_popularity                                                 59
# average_song_popularity                                            44.3947
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                          31
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  1
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    0
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 1
# writer                                                       ['Smrtdeath']
#
#                                                                      4      \
# ARTIST                                                           Smrtdeath
# ISRC                                                          QZANL1773973
# SPOTIFY_ID                                          3gjrflTTriqZ9d30uSF4hP
# TITLE                                                 Went & Got Some More
# lyrics                   \n\n[Hook: Smrtdeath]\nI just lost some drugs,...
# song_id                                                            3256462
# producer                   ['Eternal Night', 'Sorry If I Waste Your Time']
# number_of_tracks                                                        10
# number_of_albums                                                        10
# number_of_playlists                                                     30
# playlist_followers                                                  425030
# highest_song_popularity                                                 59
# average_song_popularity                                            44.3947
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                          30
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  1
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    0
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 1
# writer                                  ['Drippin so pretty', 'Smrtdeath']
#
#                                                                      5      \
# ARTIST                                                         The Wurzels
# ISRC                                                          GBAYE7600189
# SPOTIFY_ID                                          2rnCUXbNsgjiHceaONPnJi
# TITLE                                                        The Blackbird
# lyrics                   \n\n[Chorus]\nWhere be that Blackbird to?\nI k...
# song_id                                                             110268
# producer                                                   ['Bob Barratt']
# number_of_tracks                                                         6
# number_of_albums                                                         6
# number_of_playlists                                                     16
# playlist_followers                                                   26208
# highest_song_popularity                                                 36
# average_song_popularity                                            24.7368
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                          29
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    1
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 0
# writer                        ['Pete Budd', 'Tony Baylis', 'Tommy Banner']
#
#                                                                      6      \
# ARTIST                                                              Chynna
# ISRC                                                          USYBL1800845
# SPOTIFY_ID                                          09H9FCCUpK52C3shLJXhce
# TITLE                                                        Regina George
# lyrics                   \n\n[Verse 1]\nYou niggas is way too neurotic\...
# song_id                                                            2848377
# producer                                                       ['Langsta']
# number_of_tracks                                                        19
# number_of_albums                                                        13
# number_of_playlists                                                     45
# playlist_followers                                                  183370
# highest_song_popularity                                                 41
# average_song_popularity                                            28.0484
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                          31
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  1
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    1
# Pop                                                                      0
# R&B                                                                      1
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 0
# writer                                                                  []
#
#                                                                      7      \
# ARTIST                                                          Parisalexa
# ISRC                                                          GBKPL1807679
# SPOTIFY_ID                                          1QCXiEpChPbu2WqFskChiU
# TITLE                                                             Hard Way
# lyrics                   \n\n[Intro]\nGuess you found out the hard way\...
# song_id                                                            3780171
# producer                                                   ['Elan Wright']
# number_of_tracks                                                         6
# number_of_albums                                                         4
# number_of_playlists                                                     16
# playlist_followers                                                 1580518
# highest_song_popularity                                                 54
# average_song_popularity                                            37.8824
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                          31
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    0
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            1
# Explicit                                                                 1
# writer                                                      ['Parisalexa']
#
#                                                                      8      \
# ARTIST                                                          Parisalexa
# ISRC                                                          GBKPL1807677
# SPOTIFY_ID                                          5hj5NTsV7cHyBDDCZUFwOE
# TITLE                                                                   Lv
# lyrics                   \n\n[Verse 1]\nI ain’t flexing like these bitc...
# song_id                                                            3779878
# producer                                                                []
# number_of_tracks                                                         6
# number_of_albums                                                         4
# number_of_playlists                                                     16
# playlist_followers                                                 1580518
# highest_song_popularity                                                 54
# average_song_popularity                                            37.8824
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                          29
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    0
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            1
# Explicit                                                                 0
# writer                                                      ['Parisalexa']
#
#                                                                      9      \
# ARTIST                                                     Drug Restaurant
# ISRC                                                          KRA381701828
# SPOTIFY_ID                                          2qdx4L9dFJ62uaCLHemk50
# TITLE                                                 Ain't I good to you?
# lyrics                   \n\nI'm looking for someone\nBut I think there...
# song_id                                                            3182646
# producer                                                                []
# number_of_tracks                                                        11
# number_of_albums                                                         3
# number_of_playlists                                                      9
# playlist_followers                                                   37903
# highest_song_popularity                                                 45
# average_song_popularity                                               37.6
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                          31
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    1
# Pop                                                                      1
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 0
# writer                                                                  []
#
#                                                ...                          \
# ARTIST                                         ...
# ISRC                                           ...
# SPOTIFY_ID                                     ...
# TITLE                                          ...
# lyrics                                         ...
# song_id                                        ...
# producer                                       ...
# number_of_tracks                               ...
# number_of_albums                               ...
# number_of_playlists                            ...
# playlist_followers                             ...
# highest_song_popularity                        ...
# average_song_popularity                        ...
# A_Level_Artist?                                ...
# B_Level Artist?                                ...
# max_popularity                                 ...
# Blues                                          ...
# Christian/Gospel                               ...
# Country                                        ...
# Dance/Electro                                  ...
# Disco                                          ...
# Dutch-House                                    ...
# Folk                                           ...
# Hip-Hop                                        ...
# Indie                                          ...
# Jazz                                           ...
# Latin                                          ...
# Metal                                          ...
# Other                                          ...
# Pop                                            ...
# R&B                                            ...
# Reggae                                         ...
# Rock/Alt                                       ...
# Rock/Alt/Pop                                   ...
# Singer-Songwriter                              ...
# genre_missing                                  ...
# Explicit                                       ...
# writer                                         ...
#
#                                                                      14147  \
# ARTIST                                                       The Quireboys
# ISRC                                                          FR4GL1097326
# SPOTIFY_ID                                          5Gd62mupOYVwWagspxIz2H
# TITLE                                                     Tramps & Thieves
# lyrics                   \n\nTwo lovin' eyes just as cold as stone\nAnd...
# song_id                                                            2118121
# producer                                                                []
# number_of_tracks                                                        60
# number_of_albums                                                        20
# number_of_playlists                                                     39
# playlist_followers                                                  451745
# highest_song_popularity                                                 42
# average_song_popularity                                             19.562
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                           5
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    1
# Other                                                                    0
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 1
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 0
# writer                                                                  []
#
#                                                                      14148  \
# ARTIST                                                         John Rutter
# ISRC                                                          DEN960530903
# SPOTIFY_ID                                          5ebh9MQyZRUTxXPlnfEG09
# TITLE                                      The Lord Bless You and Keep You
# lyrics                   \n\nThe Lord bless you and keep you;\nThe Lord...
# song_id                                                            2125244
# producer                                                                []
# number_of_tracks                                                       218
# number_of_albums                                                        44
# number_of_playlists                                                    132
# playlist_followers                                                  604194
# highest_song_popularity                                                 49
# average_song_popularity                                            5.91356
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                           5
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    1
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 0
# writer                                                                  []
#
#                                                                      14149  \
# ARTIST                                                          Sam Scares
# ISRC                                                          ES20D1802708
# SPOTIFY_ID                                          7i336APZwo4TGJWfui7gIV
# TITLE                                                              Save Me
# lyrics                   \n\nIntro:   Fire’s burning all around\nAshes ...
# song_id                                                            3373068
# producer                                                       ['Sam Sun']
# number_of_tracks                                                         1
# number_of_albums                                                         1
# number_of_playlists                                                      2
# playlist_followers                                                    3148
# highest_song_popularity                                                  1
# average_song_popularity                                                  1
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                           4
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    0
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            1
# Explicit                                                                 0
# writer                                                         ['Sam Sun']
#
#                                                                      14150  \
# ARTIST                                                              T-Love
# ISRC                                                          FR6V80454356
# SPOTIFY_ID                                          4VDdDk5nrSJJltq0EQNwO4
# TITLE                                                       LA to Brooklyn
# lyrics                   \n\nUh.. uhh, uhh, uhh\nCheck it out, Wee Bee ...
# song_id                                                              44528
# producer                                                                []
# number_of_tracks                                                         6
# number_of_albums                                                         4
# number_of_playlists                                                      5
# playlist_followers                                                    2774
# highest_song_popularity                                                 21
# average_song_popularity                                            6.66667
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                           4
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    0
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            1
# Explicit                                                                 1
# writer                                                                  []
#
#                                                                      14151  \
# ARTIST                                                          Blue Cheer
# ISRC                                                          DESK99110110
# SPOTIFY_ID                                          4OSr4h05qIT71OrlSMdpXI
# TITLE                                                            Foxy Lady
# lyrics                   \n\n(Jimi Hendrix)\n(Oh yeah, baby! So foxy!)\...
# song_id                                                            1176090
# producer                                                                []
# number_of_tracks                                                        20
# number_of_albums                                                        16
# number_of_playlists                                                     78
# playlist_followers                                                  523958
# highest_song_popularity                                                 36
# average_song_popularity                                            19.6897
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                           4
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    1
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 1
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 0
# writer                                                                  []
#
#                                                                      14152  \
# ARTIST                                                 Fairport Convention
# ISRC                                                          GBAAN7100057
# SPOTIFY_ID                                          7rzv0WqoEPixRdUWZDqGJF
# TITLE                                                 The Bonny Black Hare
# lyrics                   \n\nOn the fourteenth of May at the dawn of th...
# song_id                                                            1368388
# producer                                                                []
# number_of_tracks                                                        48
# number_of_albums                                                        33
# number_of_playlists                                                    106
# playlist_followers                                                  823232
# highest_song_popularity                                                 42
# average_song_popularity                                            14.6562
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                           3
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     1
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    1
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 1
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 0
# writer                                                                  []
#
#                                                                      14153  \
# ARTIST                                                              Elaiza
# ISRC                                                          DEOS71300139
# SPOTIFY_ID                                          0wzQzhX3WSZ7uWmFIXi0Rc
# TITLE                                                                Green
# lyrics                   \n\nPut my feet\nOn the earth\nSun is shining\...
# song_id                                                            1669066
# producer                                                                []
# number_of_tracks                                                         8
# number_of_albums                                                         9
# number_of_playlists                                                     51
# playlist_followers                                                   44269
# highest_song_popularity                                                 34
# average_song_popularity                                            27.0189
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                           2
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    0
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            1
# Explicit                                                                 0
# writer                                                                  []
#
#                                                                      14154  \
# ARTIST                                                           Al Bowlly
# ISRC                                                          DEKB71552068
# SPOTIFY_ID                                          68qF5qHKAzPMIsXWIF4HXx
# TITLE                                           Midnight The Stars And You
# lyrics                   \n\nMidnight with the stars and you\nMidnight ...
# song_id                                                             154214
# producer                                                     ['Al Bowlly']
# number_of_tracks                                                       104
# number_of_albums                                                        57
# number_of_playlists                                                     75
# playlist_followers                                                  397801
# highest_song_popularity                                                 41
# average_song_popularity                                            9.57353
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                           2
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     1
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    1
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 0
# writer                                                       ['Ray Noble']
#
#                                                                      14155  \
# ARTIST                                                            Robin S.
# ISRC                                                          FRR849313400
# SPOTIFY_ID                                          78GtFNaHbNE0TTUiIM3MI0
# TITLE                                                            Luv 4 Luv
# lyrics                   \n\nOh, I need somebody, somebody, yeah\n\nIt'...
# song_id                                                            1367736
# producer                                       ['Champion, Big Beat, ZYX']
# number_of_tracks                                                         2
# number_of_albums                                                         5
# number_of_playlists                                                      5
# playlist_followers                                                   11139
# highest_song_popularity                                                 23
# average_song_popularity                                            6.33333
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                           2
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    0
# Pop                                                                      0
# R&B                                                                      0
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            1
# Explicit                                                                 0
# writer                                    ['Allan George, Fred McFarlane']
#
#                                                                      14156
# ARTIST                                                         Freda Payne
# ISRC                                                          FR2X41526100
# SPOTIFY_ID                                          35FoFhttID8m3mqW9fhunI
# TITLE                                                    Deeper And Deeper
# lyrics                   \n\nDeeper and deeper\nI'm falling in love wit...
# song_id                                                            1175771
# producer                                                                []
# number_of_tracks                                                        25
# number_of_albums                                                        30
# number_of_playlists                                                    128
# playlist_followers                                                  362170
# highest_song_popularity                                                 45
# average_song_popularity                                            18.4926
# A_Level_Artist?                                                          0
# B_Level Artist?                                                          0
# max_popularity                                                           2
# Blues                                                                    0
# Christian/Gospel                                                         0
# Country                                                                  0
# Dance/Electro                                                            0
# Disco                                                                    0
# Dutch-House                                                              0
# Folk                                                                     0
# Hip-Hop                                                                  0
# Indie                                                                    0
# Jazz                                                                     0
# Latin                                                                    0
# Metal                                                                    0
# Other                                                                    0
# Pop                                                                      0
# R&B                                                                      1
# Reggae                                                                   0
# Rock/Alt                                                                 0
# Rock/Alt/Pop                                                             0
# Singer-Songwriter                                                        0
# genre_missing                                                            0
# Explicit                                                                 0
# writer                                                                  []
#
# [38 rows x 14157 columns]

# %%
a=pd.read_csv('14850_with_popluarity.csv')

# %%
b=pd.read_csv('verified_english_lyrics.csv')

# %%
m=pd.merge(a,b,on='ISRC',how='inner')

# %%
m.to_csv('mrgd.csv')

# %%
lyr=pd.read_csv('merged_eng_lyrics_genre_explicit.csv')

# %%
lyr.T
# Out:
#                                                                0      \
# song_id                                                      3727054
# lyrics             \n\n(It's Frankie! Frankie! Frankie!)\n\nHenry...
# ISRC                                                    TCADQ1846573
# SPOTIFY_ID                                    2iZBfDVGWjnQDDOdeddmSB
# TITLE                                                Lets Meet Outro
# ARTIST                                                         Lil B
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            1
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              1
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            0
# Explicit                                                        True
#
#                                                                1      \
# song_id                                                      3727036
# lyrics             \n\n[Intro]\nAye, going, going, going\nAye, sh...
# ISRC                                                    TCADQ1846536
# SPOTIFY_ID                                    7E9ebOZGFfKIu9iIcS2PVh
# TITLE                                                    Still Going
# ARTIST                                                         Lil B
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            1
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              1
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            0
# Explicit                                                        True
#
#                                                                2      \
# song_id                                                        63907
# lyrics             \n\nIntro:\n\nWhite flame, you fuck with me im...
# ISRC                                                    TCADP1826505
# SPOTIFY_ID                                    13bHrmEQDArwEPb84maY8R
# TITLE                                               Tiny Pants Bitch
# ARTIST                                                         Lil B
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            1
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              1
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            0
# Explicit                                                        True
#
#                                                                3      \
# song_id                                                      3727044
# lyrics             \n\n[Intro]\nThis that sound\nThis that pop sh...
# ISRC                                                    TCADQ1846558
# SPOTIFY_ID                                    6rapmfw88wWE65sJVPVA6E
# TITLE                                Riding Skating Rolling Painting
# ARTIST                                                         Lil B
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            1
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              1
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            0
# Explicit                                                        True
#
#                                                                4      \
# song_id                                                      3727032
# lyrics             \n\nFrankie Joseph: [knocking on door]\nGodfat...
# ISRC                                                    TCADQ1846529
# SPOTIFY_ID                                    5LlmpZACRuFeIKjt8xnqjB
# TITLE                                                  Made Man Skit
# ARTIST                                                         Lil B
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            1
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              1
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            0
# Explicit                                                        True
#
#                                                                5      \
# song_id                                                         2881
# lyrics             \n\n[Intro]\nJust for now, just for now, just ...
# ISRC                                                    TCADP1842617
# SPOTIFY_ID                                    5pIpewM8Pq4Xxn6yMN2uJx
# TITLE                                          B.O.R. (Birth of Rap)
# ARTIST                                                         Lil B
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            1
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              1
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            0
# Explicit                                                        True
#
#                                                                6      \
# song_id                                                      3727051
# lyrics             \n\n[Intro]\nWe need everybody to get to the d...
# ISRC                                                    TCADQ1846568
# SPOTIFY_ID                                    1hRufLvBAdri2WkwpKWUQ6
# TITLE                                                       Red Bull
# ARTIST                                                         Lil B
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            1
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              1
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            0
# Explicit                                                        True
#
#                                                                7      \
# song_id                                                       416205
# lyrics             \n\n[Hook]\nCall me Katy Perry (x8)\n\n[Verse ...
# ISRC                                                    TCADP1838390
# SPOTIFY_ID                                    1RRzflnFPqV2M4yBogMD6J
# TITLE                                                     Katy Perry
# ARTIST                                                         Lil B
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            1
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              1
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            0
# Explicit                                                        True
#
#                                                                8      \
# song_id                                                         3591
# lyrics             \n\n[Verse 1: Lil B]\nI don't care; I get head...
# ISRC                                                    TCADP1821011
# SPOTIFY_ID                                    4tW7l8mFdCoBkRMODYU4UM
# TITLE                                                        Im Heem
# ARTIST                                                         Lil B
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            1
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              1
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            0
# Explicit                                                        True
#
#                                                                9      \
# song_id                                                      3086860
# lyrics             \n\n[Sample]\nRemember, there's always tomorro...
# ISRC                                                    TCADP1834600
# SPOTIFY_ID                                    1RcXDJekpkcCbmGYE7Sqhh
# TITLE                                                   1000 Bitches
# ARTIST                                                         Lil B
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            1
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              1
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            0
# Explicit                                                        True
#
#                                          ...                          \
# song_id                                  ...
# lyrics                                   ...
# ISRC                                     ...
# SPOTIFY_ID                               ...
# TITLE                                    ...
# ARTIST                                   ...
# Blues                                    ...
# Christian/Gospel                         ...
# Classical                                ...
# Country                                  ...
# Dance/Electro                            ...
# Disco                                    ...
# Dutch-House                              ...
# Folk                                     ...
# Funk                                     ...
# Hip-Hop                                  ...
# Indie                                    ...
# Jazz                                     ...
# Latin                                    ...
# Metal                                    ...
# Other                                    ...
# Pop                                      ...
# R&B                                      ...
# Reggae                                   ...
# Rock/Alt                                 ...
# Rock/Alt/Pop                             ...
# Sertanejo                                ...
# Singer-Songwriter                        ...
# Sleep                                    ...
# missing                                  ...
# Explicit                                 ...
#
#                                                                97346  \
# song_id                                                        60070
# lyrics             \n\nI'm on my Soulja Boy shit, but a lot sicke...
# ISRC                                                    QMWZB1711807
# SPOTIFY_ID                                    1UIg9QWbWPW0SoEUbbgz5f
# TITLE                                                     Love Child
# ARTIST                                                   Freddy Rule
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            0
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              0
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            1
# Explicit                                                       False
#
#                                                                97347  \
# song_id                                                      1478710
# lyrics             \n\nWell, its not the love\nIts the feeling\...
# ISRC                                                    USA2B0934501
# SPOTIFY_ID                                    5fu23TjDWzXTzVJMoUTtDb
# TITLE                                           Henry's Funeral Shoe
# ARTIST                                          Henry's Funeral Shoe
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            0
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              1
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            0
# Explicit                                                       False
#
#                                                                97348  \
# song_id                                                      2215590
# lyrics             \n\n[Intro]\nI see I gotta play another game, ...
# ISRC                                                    QM4DW1845810
# SPOTIFY_ID                                    241YkKtpymQwmrFd9wBqyX
# TITLE                                                     Be the One
# ARTIST                                             Vibes on the Hhil
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            0
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              0
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            1
# Explicit                                                        True
#
#                                                                97349  \
# song_id                                                       541909
# lyrics             \n\nCitation: 458 U.S. 419\n\nJUSTICE MARSHALL...
# ISRC                                                    CA5KR1811926
# SPOTIFY_ID                                    2RWMRtneos7OdGAycbZTy8
# TITLE                                                    Requisition
# ARTIST                                                Paradigm Shift
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            0
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              0
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            1
# Explicit                                                       False
#
#                                                                97350  \
# song_id                                                      2940888
# lyrics             \n\nIntro: Is this thing on?\nSo they can hear...
# ISRC                                                    US2S71165011
# SPOTIFY_ID                                    0jWwPmY0pMafBpTq5DbOfO
# TITLE                                                         People
# ARTIST                                                    Super Kidd
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            0
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              1
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            0
# Explicit                                                       False
#
#                                                                97351  \
# song_id                                                        17785
# lyrics             \n\nDear Sweetheart\n\n[ VERSE 1 ]\nHow you're...
# ISRC                                                    NLH7S1800002
# SPOTIFY_ID                                    7Bk0FuqDKdHFvBA9cpA4Qg
# TITLE                                                One Night Stand
# ARTIST                                                          Haas
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            0
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              0
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            1
# Explicit                                                       False
#
#                                                                97352  \
# song_id                                                      1423061
# lyrics             \n\nA clustered mind is not a benefical one\nI...
# ISRC                                                    FR8GU1700064
# SPOTIFY_ID                                    6mGE1BwW8SRXcOZzzsI8zR
# TITLE                                                   Live Without
# ARTIST                                                        Marlin
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            0
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              0
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            1
# Explicit                                                       False
#
#                                                                97353  \
# song_id                                                      2489368
# lyrics             \n\nSTK, Uh Skill i'm on it, Jay Bull, Bebelin...
# ISRC                                                    GBLFP1852810
# SPOTIFY_ID                                    1gA6XVNYf25weTcp59SDcA
# TITLE                                                      Go Get It
# ARTIST                                                            Y3
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            0
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              0
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            1
# Explicit                                                        True
#
#                                                                97354  \
# song_id                                                      1578822
# lyrics             \n\nNightfall tries to paint the dying skies\n...
# ISRC                                                    QM4DW1876084
# SPOTIFY_ID                                    37VeDmKTmI3WBfBX6KYl15
# TITLE                                               You'll Always Be
# ARTIST                                                 Magnetic East
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            0
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              0
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            1
# Explicit                                                        True
#
#                                                                97355
# song_id                                                       596640
# lyrics             \n\nINSTITUTES OF THE CHRISTIAN RELIGION\n\nBO...
# ISRC                                                    TCADQ1854338
# SPOTIFY_ID                                    4tHnhwmZNOtVx9M8hdnWIn
# TITLE                                                          Faith
# ARTIST                                              Victor Cornelius
# Blues                                                              0
# Christian/Gospel                                                   0
# Classical                                                          0
# Country                                                            0
# Dance/Electro                                                      0
# Disco                                                              0
# Dutch-House                                                        0
# Folk                                                               0
# Funk                                                               0
# Hip-Hop                                                            0
# Indie                                                              0
# Jazz                                                               0
# Latin                                                              0
# Metal                                                              0
# Other                                                              0
# Pop                                                                0
# R&B                                                                0
# Reggae                                                             0
# Rock/Alt                                                           0
# Rock/Alt/Pop                                                       0
# Sertanejo                                                          0
# Singer-Songwriter                                                  0
# Sleep                                                              0
# missing                                                            1
# Explicit                                                       False
#
# [31 rows x 97356 columns]

# %%
blues=lyr[lyr['Blues']==1]['lyrics']
cg=lyr[lyr['Christian/Gospel']==1]['lyrics']
country=lyr[lyr['Country']==1]['lyrics']
de=lyr[lyr['Dance/Electro']==1]['lyrics']
disco=lyr[lyr['Disco']==1]['lyrics']
dh=lyr[lyr['Dutch-House']==1]['lyrics']
folk=lyr[lyr['Folk']==1]['lyrics']
hiphop=lyr[lyr['Hip-Hop']==1]['lyrics']
indie=lyr[lyr['Indie']==1]['lyrics']
jazz=lyr[lyr['Jazz']==1]['lyrics']  
latin=lyr[lyr['Latin']==1]['lyrics']
metal=lyr[lyr['Metal']==1]['lyrics']
other=lyr[lyr['Other']==1]['lyrics']
pop=lyr[lyr['Pop']==1]['lyrics']
rb=lyr[lyr['R&B']==1]['lyrics']
reggae=lyr[lyr['Reggae']==1]['lyrics']
ra=lyr[lyr['Rock/Alt']==1]['lyrics']
rap=lyr[lyr['Rock/Alt/Pop']==1]['lyrics']
missing=lyr[lyr['missing']==1]['lyrics']
explicit=lyr[lyr['Explicit']==1]['lyrics']

# %%
# !pip install langdetect
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: langdetect in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (1.0.7)
# Requirement already satisfied: six in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from langdetect) (1.11.0)
# Requirement already satisfied: spacy in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (2.0.12)
# Requirement already satisfied: numpy>=1.7 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from spacy) (1.15.2)
# Requirement already satisfied: regex==2017.4.5 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from spacy) (2017.4.5)
# Requirement already satisfied: thinc<6.11.0,>=6.10.3 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from spacy) (6.10.3)
# Requirement already satisfied: dill<0.3,>=0.2 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from spacy) (0.2.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from spacy) (2.19.1)
# Requirement already satisfied: preshed<2.0.0,>=1.0.0 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from spacy) (1.0.1)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from spacy) (0.9.6)
# Requirement already satisfied: murmurhash<0.29,>=0.28 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from spacy) (0.28.0)
# Requirement already satisfied: ujson>=1.35 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from spacy) (1.35)
# Requirement already satisfied: cymem<1.32,>=1.30 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from spacy) (1.31.2)
# Requirement already satisfied: msgpack<1.0.0,>=0.5.6 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy) (0.5.6)
# Requirement already satisfied: wrapt<1.11.0,>=1.10.0 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy) (1.10.11)
# Requirement already satisfied: cytoolz<0.10,>=0.9.0 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy) (0.9.0.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy) (4.26.0)
# Requirement already satisfied: six<2.0.0,>=1.10.0 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy) (1.11.0)
# Requirement already satisfied: msgpack-numpy<1.0.0,>=0.4.1 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from thinc<6.11.0,>=6.10.3->spacy) (0.4.4.1)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.23)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2018.8.24)
# Requirement already satisfied: idna<2.8,>=2.5 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7)
# Requirement already satisfied: toolz>=0.8.0 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.11.0,>=6.10.3->spacy) (0.9.0)
# Requirement already satisfied: en_core_web_sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz#egg=en_core_web_sm==2.0.0 in /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages (2.0.0)
#
#     Linking successful
#     /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages/en_core_web_sm
#     -->
#     /Users/preetgandhi95/miniconda3/envs/nlpclass/lib/python3.6/site-packages/spacy/data/en_core_web_sm
#
#     You can now load the model via spacy.load('en_core_web_sm')

# %%
#from nltk import wordpunct_tokenize
from nltk import word_tokenize
from nltk.corpus import stopwords
import re

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string

exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()

# %%
stop = {'\n','\t','ourselves', 'hers', 'between', 'yourself', 'but', 'again', 'there', 
           'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an',
           'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself',
           'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 
           'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 
           'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 
           'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all',
           'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 
           'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 
           'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has',
           'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few',
           'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it',
           'how', 'further', 'was', 'here', 'than'}

# %%
# # Let's write the tokenization function 
# # set a hyperparameter - vocab size of dataset
# #Takes most frequent 10000 words from training set and makes it a vocabulary
# #Other words are put as unknown token.
# #One for unknown and one for padding and 9998 for most frequent words
# #Spacy will be used for tokenisation
# stop = {'\n','\t','ourselves', 'hers', 'between', 'yourself', 'but', 'again', 'there', 
#            'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an',
#            'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself',
#            'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 
#            'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 
#            'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 
#            'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all',
#            'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 
#            'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 
#            'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has',
#            'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few',
#            'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it',
#            'how', 'further', 'was', 'here', 'than'}
# import spacy
# import string

# # Load English tokenizer, tagger, parser, NER and word vectors
# tokenizer = spacy.load('en_core_web_sm')
# punctuations = string.punctuation

# # lowercase and remove punctuation
# def tokenize(sent):
#     tokens = tokenizer(sent)
#     u= [token.text.lower() for token in tokens if (token.text not in punctuations)]
#     ty= [token for token in u if (token not in stop)]
#     return ty

# import nltk
# nltk.download('wordnet')
# doc_complete=[]
# for i in range(0,len(pop)):
#     doc_complete.append(tokenize(pop.iloc[i]))

# %%
import nltk
nltk.download('wordnet')
doc_complete=[]
for i in range(0,len(blues)):
    doc_complete.append(blues.iloc[i])
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/preetgandhi95/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

doc_clean = [clean(doc).split() for doc in doc_complete]

# %%
# Importing Gensim
import gensim
from gensim import corpora

# Creating the term dictionary of our corpus, where every unique term is assigned an index. 
dictionary = corpora.Dictionary(doc_clean)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=3, id2word = dictionary, passes=50)

# %%
ldamodel_blues=ldamodel

# %%
from gensim.test.utils import datapath
# Save model to disk.
temp_file = datapath("blues")
ldamodel.save(temp_file)
# Load a potentially pretrained model from disk.
#lda = LdaModel.load(temp_file)

# %%
print(ldamodel.print_topics(num_topics=3, num_words=3))
# Out:
# [(0, '0.013*"im" + 0.011*"like" + 0.010*"know"'), (1, '0.007*"would" + 0.004*"p" + 0.004*"one"'), (2, '0.014*"sarah" + 0.006*"hoggle" + 0.004*"one"')]

# %%
ldamodel.print_topics(num_topics=5, num_words=10)
# Out:
# [(0,
#   '0.013*"im" + 0.011*"like" + 0.010*"know" + 0.010*"it" + 0.008*"get" + 0.008*"dont" + 0.008*"baby" + 0.008*"got" + 0.007*"love" + 0.006*"go"'),
#  (1,
#   '0.007*"would" + 0.004*"p" + 0.004*"one" + 0.003*"could" + 0.003*"king" + 0.003*"u" + 0.003*"him" + 0.003*"upon" + 0.003*"v" + 0.003*"great"'),
#  (2,
#   '0.014*"sarah" + 0.006*"hoggle" + 0.004*"one" + 0.004*"it" + 0.003*"see" + 0.003*"jessica" + 0.003*"ludo" + 0.003*"jareth" + 0.003*"look" + 0.003*"luke"')]

# %%
import nltk
nltk.download('wordnet')
doc_complete=[]
for i in range(0,len(cg)):
    doc_complete.append(cg.iloc[i])
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/preetgandhi95/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

doc_clean = [clean(doc).split() for doc in doc_complete]

# %%
# Importing Gensim
import gensim
from gensim import corpora

# Creating the term dictionary of our corpus, where every unique term is assigned an index. 
dictionary = corpora.Dictionary(doc_clean)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=3, id2word = dictionary, passes=50)

# %%
ldamodel_cg=ldamodel

# %%
print(ldamodel.print_topics(num_topics=3, num_words=3))
# Out:
# [(0, '0.010*"love" + 0.009*"im" + 0.007*"it"'), (1, '0.006*"one" + 0.005*"king" + 0.004*"god"'), (2, '0.005*"one" + 0.004*"said" + 0.004*"would"')]

# %%
ldamodel.print_topics(num_topics=5, num_words=10)
# Out:
# [(0,
#   '0.010*"love" + 0.009*"im" + 0.007*"it" + 0.007*"know" + 0.007*"god" + 0.007*"state" + 0.006*"see" + 0.006*"u" + 0.006*"one" + 0.006*"lord"'),
#  (1,
#   '0.006*"one" + 0.005*"king" + 0.004*"god" + 0.004*"men" + 0.004*"upon" + 0.004*"shall" + 0.004*"great" + 0.004*"also" + 0.004*"man" + 0.003*"time"'),
#  (2,
#   '0.005*"one" + 0.004*"said" + 0.004*"would" + 0.004*"year" + 0.003*"it" + 0.003*"time" + 0.003*"like" + 0.003*"mr" + 0.002*"could" + 0.002*"made"')]

# %%
from gensim.test.utils import datapath
# Save model to disk.
temp_file = datapath
#  (2,
#   '0.009*"like" + 0.005*"it" + 0.005*"la" + 0.004*"da" + 0.004*"got" + 0.004*"rat" + 0.003*"shit" + 0.003*"mole" + 0.003*"im" + 0.003*"never" + 0.003*"said" + 0.003*"duck" + 0.003*"one" + 0.003*"made" + 0.003*"feck" + 0.003*"little" + 0.002*"verse" + 0.002*"people" + 0.002*"really" + 0.002*"yo"')]

# %%
from gensim.test.utils import datapath
# Save model to disk.
temp_file = datapath("rap")
ldamodel.save(temp_file)
# Load a potentially pretrained model from disk.
#lda = LdaModel.load(temp_file)

# %%
import nltk
nltk.download('wordnet')
doc_complete=[]
for i in range(0,len(explicit)):
    doc_complete.append(explicit.iloc[i])
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

doc_clean = [clean(doc).split() for doc in doc_complete]   

def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

doc_clean = [clean(doc).split() for doc in doc_complete]   
# Importing Gensim
import gensim
from gensim import corpora

# Creating the term dictionary of our corpus, where every unique term is assigned an index. 
dictionary = corpora.Dictionary(doc_clean)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=3, id2word = dictionary, passes=50)

ldamodel_explicit=ldamodel
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/preetgandhi95/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
print(ldamodel.print_topics(num_topics=3, num_words=3))
# Out:
# [(0, '0.006*"one" + 0.005*"would" + 0.004*"said"'), (1, '0.020*"im" + 0.017*"like" + 0.012*"nigga"'), (2, '0.025*"i’m" + 0.014*"don’t" + 0.011*"it’s"')]

# %%
ldamodel.print_topics(num_topics=5, num_words=20)
# Out:
# [(0,
#   '0.006*"one" + 0.005*"would" + 0.004*"said" + 0.004*"it" + 0.003*"man" + 0.003*"time" + 0.003*"u" + 0.003*"could" + 0.003*"people" + 0.003*"thing" + 0.002*"may" + 0.002*"him" + 0.002*"see" + 0.002*"say" + 0.002*"well" + 0.002*"god" + 0.002*"upon" + 0.002*"you" + 0.002*"day" + 0.002*"come"'),
#  (1,
#   '0.020*"im" + 0.017*"like" + 0.012*"nigga" + 0.011*"got" + 0.011*"get" + 0.010*"know" + 0.010*"dont" + 0.010*"it" + 0.007*"bitch" + 0.007*"shit" + 0.007*"aint" + 0.006*"yeah" + 0.006*"verse" + 0.006*"fuck" + 0.005*"go" + 0.005*"back" + 0.005*"see" + 0.004*"man" + 0.004*"make" + 0.004*"cause"'),
#  (2,
#   '0.025*"i’m" + 0.014*"don’t" + 0.011*"it’s" + 0.006*"that’s" + 0.005*"can’t" + 0.005*"you’re" + 0.005*"ain’t" + 0.004*"music" + 0.004*"i’ll" + 0.004*"la" + 0.003*"–" + 0.003*"na" + 0.003*"i’ve" + 0.002*"2" + 0.002*"de" + 0.002*"album" + 0.002*"we’re" + 0.002*"•" + 0.002*"won’t" + 0.002*"y’all"')]

# %%
from gensim.test.utils import datapath
# Save model to disk.
temp_file = datapath("explicit")
ldamodel.save(temp_file)
# Load a potentially pretrained model from disk.
#lda = LdaModel.load(temp_file)
